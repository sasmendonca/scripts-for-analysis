# %% [markdown]
# Physcochemical properties analysis

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload
from py_code.property_analysis import load_and_process_data, calculate_descriptors, generate_plots, generate_report
import logging

file_path = './input/Mpro-postera-chemic50-continuous.sdf'

#%% Load and process data
df = load_and_process_data(file_path)

#%% Calculate descriptors
print("\nCalculating descriptors...")
df = calculate_descriptors(df)

#%% Display data
print("\nFirst rows with descriptors:")
display(df.head())

#%% Generate visualizations
print("\nGenerating visualizations...")
generate_plots(df)

#%% Generate report (optional)
print("\nGenerating complete report...")
report_path = generate_report(df, filename='Mpro_continuous_report.pdf')
print(f"Relatório gerado em: {report_path}")
# Out:
# [18:21:25] MRV_IMPLICIT_H SGroup on atom without aromatic bonds, 6, ignored.
# [18:21:25] MRV_IMPLICIT_H SGroup on atom without aromatic bonds, 9, ignored.
# [18:21:26] MRV_IMPLICIT_H SGroup on atom without aromatic bonds, 23, ignored.
# [18:21:26] MRV_IMPLICIT_H SGroup on atom without aromatic bonds, 13, ignored.
# [18:21:26] MRV_IMPLICIT_H SGroup on atom without aromatic bonds, 6, ignored.
# [18:21:26] MRV_IMPLICIT_H SGroup on atom without aromatic bonds, 31, ignored.
# [18:21:26] MRV_IMPLICIT_H SGroup on atom without aromatic bonds, 14, ignored.
# [18:21:26] MRV_IMPLICIT_H SGroup on atom without aromatic bonds, 21, ignored.
# [18:21:26] MRV_IMPLICIT_H SGroup on atom without aromatic bonds, 8, ignored.
# [18:21:26] MRV_IMPLICIT_H SGroup on atom without aromatic bonds, 29, ignored.
# [18:21:26] MRV_IMPLICIT_H SGroup on atom without aromatic bonds, 5, ignored.
# [18:21:26] MRV_IMPLICIT_H SGroup on atom without aromatic bonds, 29, ignored.
# ...
